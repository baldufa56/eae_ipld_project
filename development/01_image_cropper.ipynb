# %% [markdown]
# # Project 1: Image Cropper
#
# In this project we will be using NumPy to transform an image into an array, extract some basic information from it like its shape and size, and then crop it with a custom size. We will also be using PIL to read the image and Matplotlib to display it.
#
# There will be a default image to start with but this program shoud be able to work with any image.
#
# ### Project Tasks:
#
# - `1.1.` Take the image array `img_arr` and get its shape and size.
#
# - `1.2.` Define the dimensions of the crop, make sure that min is smaller than max and also that min is larger than 0 and max is smaller than the size of the image for every dimension. If not, print a message explaining the error.
#
# - `1.3.` Crop the image into a new array and display it.
#
# - `1.4.` Save the cropped image as a new file, declaring a variable to chose the new file name.

# %%
# The library you have to use
import numpy as np

# Some extra libraries to deal with images and files
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = "../data/starry_night.png"

with Image.open(img_path) as img:
    img_arr = np.array(img)

plt.imshow(img_arr)

# %%
# Ex 1.1: Get the height and width of the image in pixels

max_height = 1100   # TODO
max_width = 1400     # TODO

print(f"Height: {max_height} pixels")
print(f"Width: {max_width} pixels")
# Out:
# Height: 1100 pixels
# Width: 1400 pixels

# %%
# Ex 1.2: Define the dimensions of the crop, make sure that min is smaller than max and also that min is larger than 0 
# and max is smaller than the size of the image for every dimension. If not, print a message explaining the error.

# Example crop dimensions, modify them to test your code
crop_min_h = 300 
crop_max_h = 1000
crop_min_w = 550
crop_max_w = 1100

# TODO: Develop the code to validate the constraints and print the error message if any constraint is invalid

error_messages = []

# Min<Max for height and width
if crop_min_h >= crop_max_h:
    error_messages.append("Error: The minimum height should be smaller than maximum height.")

if crop_min_w >= crop_max_w:
    error_messages.append("Error: The minimum width should be smaller than maximum width.")

# Min>0 for height and width
if crop_min_h <= 0:
    error_messages.append("Error: The minimum height should be larger than 0.")

if crop_min_w <= 0:
    error_messages.append("Error: The minimum width should be larger than 0.")

# Max<image height and width
if crop_max_h > max_height:
    error_messages.append("Error: The maximum height should be smaller than the image height.")

if crop_max_w > max_width:
    error_messages.append("Error: The maximum width should be smaller than the image width.")

# Print error messages if any
if error_messages:
    for error_message in error_messages:
        print(error_message)
else:
    print("All constraints are satisfied. Crop dimensions are valid.")
# Out:
# All constraints are satisfied. Crop dimensions are valid.

# %%
# Ex 1.3: Generate the crop array into a new variable, use NumPy array slicing

crop_arr = None  # TODO

if not error_messages:
    image = np.zeros((image_height, image_width, 3))  # Replace this with your actual image array or loading logic
    
    # Perform the crop using array slicing
    crop_array = image[crop_min_h:crop_max_h, crop_min_w:crop_max_w, :]

    print("Crop array generated successfully.")
else:
    for error_message in error_messages:
        print(error_message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # Ex 1.3: Generate the crop array into a new variable, use NumPy array slicing
#       3 crop_arr = None  # TODO
# ----> 5 if not error_messages:
#       6     image = np.zeros((image_height, image_width, 3))  # Replace this with your actual image array or loading logic
#       8     # Perform the crop using array slicing
#
# NameError: name 'error_messages' is not defined

# %%
# Display the cropped image

plt.imshow(crop_arr)

# %%
# Ex 1.4: Saving the cropped image into a new file, set the filename of the new image

crop_img = Image.fromarray(crop_arr)

file_name = None  # TODO: Set a file name, use a string

crop_img.save(f"../data/{file_name}.png")
